# %%
import pandas as pd

# %%
data0 = pd.read_csv("scenario0.csv")
data1 = pd.read_csv("scenario1.csv")
data2 = pd.read_csv("A3scenario2.csv")
data3 = pd.read_csv("scenario3.csv")
data4 = pd.read_csv("A3scenario4.csv")

# %%
data00 = data0['Travel_Time']
data11 = data1['Travel_Time']
data22 = data2['Travel_Time']
data33 = data3['Travel_Time']
data44 = data4['Travel_Time']
Coolio= [data00.mean(), data11.mean(),data22.mean(), data33.mean(),data44.mean()] 
Coolio
# Out:
# [231.970729078451,
#  236.74814852858097,
#  283.98300296477964,
#  373.9019512067019,
#  600.8701021330194]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(data00, bins=10)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 0');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(data11, bins=10)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 1');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(data22, bins=10)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 2');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(data33, bins=10)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 3');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(Coolio, bins=4)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 3');

# %%
import matplotlib.pyplot as plt 

x=[0,1,2,3,4]
y=[231.970729078451,
 236.74814852858097,
 283.98300296477964,
 373.9019512067019,
 600.8701021330194]
#these are the means for all scenarios
plt.plot(x,y,marker="o")
plt.xlabel("Scenario")
plt.ylabel("Travel time")
plt.title("Figure with default X labels")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.boxplot(data33)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 3');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.boxplot(data00)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 0');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.boxplot(data11)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 1');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.boxplot(data22)  # density=False would make counts
plt.ylabel('Incidence')
plt.xlabel('Travel time, Scenario 2');
