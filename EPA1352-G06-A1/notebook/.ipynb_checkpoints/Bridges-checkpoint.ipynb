# %%
import pandas as pd
import seaborn as sns
import os

# %%
B = '../data/raw/Bridges.xlsx'
Bridge = pd.read_excel(B) 
Bridge
# Out:
#       Number         StructureName          StructureType Condition of Bridge  \
# 0        1.0     Kanch pur Bridge.       PC Girder Bridge                   A
# 1        2.0   Madanpur Bridge.(L)       PC Girder Bridge                   A
# 2        3.0    Madanpur Bridge(R)       PC Girder Bridge                   A
# 3        4.0   Langalbandh Bridge.      RCC Girder Bridge                   B
# 4        5.0  Darikandi Bridge (L)       PC Girder Bridge                   A
# ...      ...                   ...                    ...                 ...
# 3188     NaN                   NaN      RCC Girder Bridge                   B
# 3189     NaN                   NaN      RCC Girder Bridge                   C
# 3190     NaN                   NaN  Truss with Steel Deck                   A
# 3191     NaN                   NaN      RCC Girder Bridge                   B
# 3192     NaN                   NaN  Baily with Steel Deck                   A
#
#       TotalWidth  TotalLength  ConstructionYear  NumberOfSpan     Zone  \
# 0          14.55       394.23            1986.0           8.0    Dhaka
# 1           9.20        27.50            2003.0           1.0    Dhaka
# 2           9.12        27.50            2007.0           1.0    Dhaka
# 3          17.80       159.52            1998.0           5.0    Dhaka
# 4           9.15        20.50            2002.0           1.0    Dhaka
# ...          ...          ...               ...           ...      ...
# 3188        4.00         6.00            1992.0           1.0  Barisal
# 3189        6.67        20.00            2013.0           1.0  Barisal
# 3190        4.21        31.07            1995.0           1.0  Barisal
# 3191        4.06        12.00            1996.0           1.0  Barisal
# 3192        5.00        27.36            2006.0           1.0  Barisal
#
#        Circle  ... LocationLRPOffset LocationChainage LatitudeDegree  \
# 0       Dhaka  ...            3976.0            8.976           23.0
# 1       Dhaka  ...             305.0           12.660           23.0
# 2       Dhaka  ...             333.0           12.688           23.0
# 3       Dhaka  ...            1672.0           17.134           23.0
# 4       Dhaka  ...            2260.0           17.222           23.0
# ...       ...  ...               ...              ...            ...
# 3188  Barisal  ...             410.0            2.310           22.0
# 3189  Barisal  ...             550.0            3.440           22.0
# 3190  Barisal  ...             305.0            6.692           22.0
# 3191  Barisal  ...            1717.0            8.104           22.0
# 3192  Barisal  ...            2070.0            2.070           22.0
#
#       LatitudeMinute LatitudeSecond LongitudeDegree  LongitudeMinute  \
# 0               42.0            7.5            90.0             30.0
# 1               41.0           28.4            90.0             32.0
# 2               41.0           28.0            90.0             32.0
# 3               39.0           33.9            90.0             34.0
# 4               39.0           21.8            90.0             34.0
# ...              ...            ...             ...              ...
# 3188            36.0           52.0            90.0             40.0
# 3189            37.0            5.0            90.0             41.0
# 3190            25.0           43.5            90.0             47.0
# 3191            25.0           48.6            90.0             46.0
# 3192            24.0           51.0            90.0             47.0
#
#       LongitudeSecond  Unnamed: 24  BCS1TotalScore
# 0                57.3          NaN             0.0
# 1                41.6          NaN             0.0
# 2                41.6          NaN             0.0
# 3                10.9          NaN            31.0
# 4                27.7          NaN             0.0
# ...               ...          ...             ...
# 3188             50.0          NaN             1.0
# 3189             25.0          NaN            30.0
# 3190             18.1          NaN             0.0
# 3191             30.3          NaN            30.0
# 3192             30.0          NaN             0.0
#
# [3193 rows x 26 columns]

# %%
# drop duplicates and keep the first ones
Bridge.drop_duplicates(subset= 'StructureName', keep = 'first',inplace=True)

# %%
# Check if there are any NAN values
print(Bridge.columns)
# Out:
# Index(['Number', 'StructureName', 'StructureType', 'Condition of Bridge',
#        'TotalWidth', 'TotalLength', 'ConstructionYear', 'NumberOfSpan', 'Zone',
#        'Circle', 'Division', 'Sub-Division', 'RoadNo', 'Unnamed: 13',
#        'StructureLRPName', 'ReferenceLRPNo', 'LocationLRPOffset',
#        'LocationChainage', 'LatitudeDegree', 'LatitudeMinute',
#        'LatitudeSecond', 'LongitudeDegree', 'LongitudeMinute',
#        'LongitudeSecond', 'Unnamed: 24', 'BCS1TotalScore'],
#       dtype='object')

# %%
# Delete the Unnamed:24 column
Bridge.drop('Unnamed: 24', inplace=True, axis=1, )

# %%
# Delete the Unnamed:13 column
Bridge.drop('Unnamed: 13', inplace=True, axis=1, )

# %%
# Drop all rows where there is a value missing
Bridge = Bridge.dropna()

# %%
# plot a histogram of the total widths of the bridges in order to identify any strange outliers
sns.histplot(data = Bridge, x= "TotalWidth")
# Out:
# <AxesSubplot:xlabel='TotalWidth', ylabel='Count'>

# %%
# check which bridges are wider than 30 meter
Bridge_width = Bridge.loc[Bridge["TotalWidth"]>30]
Bridge_width
# Out:
#       Number      StructureName      StructureType Condition of Bridge  \
# 56      57.0  Shikalbaha Bridge   PC Girder Bridge                   A
# 1309  1310.0   Bolloppur Bridge  RCC Girder Bridge                   C
#
#       TotalWidth  TotalLength  ConstructionYear  NumberOfSpan        Zone  \
# 56          31.2        17.30            2010.0           1.0  Chittagong
# 1309       428.0        10.25            1997.0           1.0     Comilla
#
#           Circle  ... ReferenceLRPNo LocationLRPOffset LocationChainage  \
# 56    Chittagong  ...         LRP238            4794.0          247.637
# 1309     Comilla  ...         LRP005            4950.0            9.950
#
#      LatitudeDegree LatitudeMinute  LatitudeSecond  LongitudeDegree  \
# 56             22.0           18.0            55.2             91.0
# 1309           23.0           34.0            17.2             90.0
#
#       LongitudeMinute  LongitudeSecond  BCS1TotalScore
# 56               51.0             19.1             0.0
# 1309             56.0             56.3            31.0
#
# [2 rows x 24 columns]

# %% [markdown]
# After checking on google these bridges, only Shikalbaha Bridge is correct, the other one is too large

# %%
# Drop the other bridge as it is too large
Bridge_widthindex = list(Bridge_width.index)
Bridge.drop(Bridge_widthindex,axis=0,inplace=True)
# Out:
# C:\Users\marlo\.anaconda\Python anaconda 3.8\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# plot a histogram of the total length of the bridges in order to identify any strange outliers
sns.histplot(data = Bridge, x= "TotalLength")
# Out:
# <AxesSubplot:xlabel='TotalLength', ylabel='Count'>

# %%
# plot bridges longer than 500 meter
Bridge_lenth = Bridge.loc[Bridge["TotalLength"]>500]
Bridge_lenth
# Out:
#       Number                StructureName        StructureType  \
# 16      17.0                Meghna Bridge     PC Girder Bridge
# 31      32.0            Daudkandi Bridge.               PC Box
# 55      56.0            Sha Amanot Bridge               PC Box
# 227    228.0               Bhairab Bridge               PC Box
# 439    440.0           Dhaleshwari Bridge    RCC Girder Bridge
# 445    446.0                  Tora Bridge     PC Girder Bridge
# 465    466.0                 Baral Bridge     PC Girder Bridge
# 581    582.0                 Garai Bridge  Truss with RCC Slab
# 609    610.0             Postagola Bridge     PC Girder Bridge
# 1115  1116.0  Mir Mosharraf Hosain Bridge  Truss with RCC Slab
# 1188  1189.0            Babu Bazar Bridge     PC Girder Bridge
# 1242  1243.0               Gabkhan Bridge     PC Girder Bridge
# 2502  2503.0                Dharla Bridge     PC Girder Bridge
#
#      Condition of Bridge  TotalWidth  TotalLength  ConstructionYear  \
# 16                     A        9.14       924.85            1989.0
# 31                     A        9.13      1408.80            1995.0
# 55                     A       24.28       954.50            2009.0
# 227                    A       19.75       924.00            2002.0
# 439                    A        7.90       506.59            1964.0
# 445                    B        9.30       645.66            1974.0
# 465                    C       10.08       573.47            1980.0
# 581                    B        8.70       612.50            1991.0
# 609                    A       17.60       847.90            1989.0
# 1115                   C       10.00       504.54            2009.0
# 1188                   A       17.60      1018.00            2000.0
# 1242                   B        9.75       910.60            2001.0
# 2502                   A       10.00       657.22            2003.0
#
#       NumberOfSpan        Zone      Circle  ... ReferenceLRPNo  \
# 16            13.0       Dhaka       Dhaka  ...         LRP023
# 31            17.0       Dhaka       Dhaka  ...         LRP036
# 55            11.0  Chittagong  Chittagong  ...         LRP238
# 227            9.0  Mymensingh  Mymensingh  ...         LRP068
# 439           11.0       Dhaka       Dhaka  ...         LRP049
# 445           11.0       Dhaka       Dhaka  ...         LRP056
# 465           15.0    Rajshahi       Pabna  ...         LRP131
# 581            7.0      Khulna     Jessore  ...         LRP064
# 609           21.0       Dhaka       Dhaka  ...         LRP001
# 1115           9.0      Khulna     Jessore  ...         LRP065
# 1188          31.0       Dhaka       Dhaka  ...           LRPS
# 1242          25.0     Barisal     Barisal  ...         LRP019
# 2502          16.0     Rangpur     Rangpur  ...         LRP004
#
#      LocationLRPOffset LocationChainage LatitudeDegree LatitudeMinute  \
# 16              1923.0           24.393           23.0           36.0
# 31              1634.0           37.010           23.0           31.0
# 55              3177.0          246.020           22.0           19.0
# 227             4427.0           71.834           24.0            2.0
# 439                9.0           48.000           23.0           52.0
# 445              859.0           55.866           23.0           51.0
# 465               92.0          129.616           24.0            8.0
# 581              729.0           65.221           23.0           32.0
# 609             1538.0            2.587           23.0           41.0
# 1115            1602.0           65.214           23.0           53.0
# 1188            1015.0            1.015           23.0           42.0
# 1242            1240.0           19.917           22.0           38.0
# 2502             267.0            3.178           25.0           49.0
#
#       LatitudeSecond  LongitudeDegree  LongitudeMinute  LongitudeSecond  \
# 16             34.30             90.0             36.0            43.80
# 31             47.50             90.0             41.0            42.50
# 55             44.90             91.0             51.0             6.00
# 227            55.84             90.0             59.0            30.15
# 439            51.60             90.0              1.0            42.90
# 445            41.50             89.0             57.0            39.00
# 465             4.00             89.0             35.0             5.00
# 581            40.00             89.0             31.0             6.00
# 609            21.70             90.0             25.0            45.90
# 1115            7.00             89.0             10.0            58.00
# 1188           17.60             90.0             23.0            56.70
# 1242           34.00             90.0             10.0            58.00
# 2502            7.00             89.0             39.0            56.00
#
#       BCS1TotalScore
# 16               0.0
# 31               0.0
# 55               0.0
# 227              0.0
# 439              0.0
# 445              1.0
# 465             30.0
# 581              1.0
# 609              0.0
# 1115           501.0
# 1188             0.0
# 1242             1.0
# 2502             0.0
#
# [13 rows x 24 columns]

# %% [markdown]
# All bridges with a length superior to 500m are actualy existing and that large.

# %%
# Drop the bridges that are longer than 500 meters
Bridge_lenthindex = list(Bridge_lenth.index)
Bridge.drop(Bridge_lenthindex,axis=0,inplace=True)
# Out:
# C:\Users\marlo\.anaconda\Python anaconda 3.8\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# There is no strange outliers identiefied for the length of the bridges.

# %%
# plot a histogram of the construction year of the bridges in order to identify any strange outliers
sns.histplot(data = Bridge, x = 'ConstructionYear')
ConstructionYear = Bridge.loc[Bridge["ConstructionYear"]>2021]
ConstructionYear
# Out:
#      Number    StructureName      StructureType Condition of Bridge  \
# 942   943.0  Saforpur Bridge  RCC Girder Bridge                   B
#
#      TotalWidth  TotalLength  ConstructionYear  NumberOfSpan    Zone  \
# 942         4.0         24.3            2080.0           3.0  Sylhet
#
#             Circle  ... ReferenceLRPNo LocationLRPOffset LocationChainage  \
# 942  Moulavi Bazar  ...         LRP038            1014.0           37.554
#
#     LatitudeDegree LatitudeMinute  LatitudeSecond  LongitudeDegree  \
# 942           24.0           37.0            31.0             92.0
#
#      LongitudeMinute  LongitudeSecond  BCS1TotalScore
# 942              8.0             59.0            30.0
#
# [1 rows x 24 columns]

# %%
# Drop the bridge that has the wrong construction date
ConstructionYearindex = list(ConstructionYear.index)
Bridge.drop(ConstructionYearindex,axis=0,inplace=True)
# Out:
# C:\Users\marlo\.anaconda\Python anaconda 3.8\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# This bridge is from 2080, need to be recoded to 1980 or deleted.

# %%
# plot the number of spans and show the ones greater than 20
sns.histplot(data = Bridge, x = 'NumberOfSpan')
NumberOfSpan = Bridge.loc[Bridge["NumberOfSpan"]>20]
NumberOfSpan
# Out:
#      Number StructureName          StructureType Condition of Bridge  \
# 346   347.0   Keen Bridge  Steel Beam & RCC Slab                   C
#
#      TotalWidth  TotalLength  ConstructionYear  NumberOfSpan    Zone  Circle  \
# 346         5.8        358.0            1936.0          22.0  Sylhet  Sylhet
#
#      ... ReferenceLRPNo LocationLRPOffset LocationChainage LatitudeDegree  \
# 346  ...         LRP058             306.0           58.496           24.0
#
#     LatitudeMinute  LatitudeSecond  LongitudeDegree  LongitudeMinute  \
# 346           53.0            10.3             91.0             52.0
#
#      LongitudeSecond  BCS1TotalScore
# 346              5.2           560.0
#
# [1 rows x 24 columns]

# %% [markdown]
# All these bridges were checked with google and are correct.

# %%
#add a column that converts the latitude degree/minutes/seconds to decimals
Bridge['LatitudeDecimal'] = Bridge['LatitudeDegree'] + (Bridge['LatitudeMinute']/60) + (Bridge['LatitudeSecond']/3600)
# Out:
# <ipython-input-29-0a2e68c2cdc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bridge['LatitudeDecimal'] = Bridge['LatitudeDegree'] + (Bridge['LatitudeMinute']/60) + (Bridge['LatitudeSecond']/3600)

# %%
#add a column that converts the longitude degree/minutes/seconds to decimals
Bridge['LongitudeDecimal'] = Bridge['LongitudeDegree'] + (Bridge['LongitudeMinute']/60) + (Bridge['LongitudeSecond']/3600)
Bridge.head()
# Out:
# <ipython-input-30-5d84f40f1132>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bridge['LongitudeDecimal'] = Bridge['LongitudeDegree'] + (Bridge['LongitudeMinute']/60) + (Bridge['LongitudeSecond']/3600)
#    Number         StructureName      StructureType Condition of Bridge  \
# 0     1.0     Kanch pur Bridge.   PC Girder Bridge                   A
# 1     2.0   Madanpur Bridge.(L)   PC Girder Bridge                   A
# 2     3.0    Madanpur Bridge(R)   PC Girder Bridge                   A
# 3     4.0   Langalbandh Bridge.  RCC Girder Bridge                   B
# 4     5.0  Darikandi Bridge (L)   PC Girder Bridge                   A
#
#    TotalWidth  TotalLength  ConstructionYear  NumberOfSpan   Zone Circle  ...  \
# 0       14.55       394.23            1986.0           8.0  Dhaka  Dhaka  ...
# 1        9.20        27.50            2003.0           1.0  Dhaka  Dhaka  ...
# 2        9.12        27.50            2007.0           1.0  Dhaka  Dhaka  ...
# 3       17.80       159.52            1998.0           5.0  Dhaka  Dhaka  ...
# 4        9.15        20.50            2002.0           1.0  Dhaka  Dhaka  ...
#
#   LocationChainage LatitudeDegree LatitudeMinute LatitudeSecond  \
# 0            8.976           23.0           42.0            7.5
# 1           12.660           23.0           41.0           28.4
# 2           12.688           23.0           41.0           28.0
# 3           17.134           23.0           39.0           33.9
# 4           17.222           23.0           39.0           21.8
#
#   LongitudeDegree  LongitudeMinute  LongitudeSecond  BCS1TotalScore  \
# 0            90.0             30.0             57.3             0.0
# 1            90.0             32.0             41.6             0.0
# 2            90.0             32.0             41.6             0.0
# 3            90.0             34.0             10.9            31.0
# 4            90.0             34.0             27.7             0.0
#
#    LatitudeDecimal  LongitudeDecimal
# 0        23.702083         90.515917
# 1        23.691222         90.544889
# 2        23.691111         90.544889
# 3        23.659417         90.569694
# 4        23.656056         90.574361
#
# [5 rows x 26 columns]

# %%
# show bridges with an odd coordinate
Bridgelatitudewrong = Bridge.loc[Bridge["LatitudeDecimal"]>27]
Bridgelatitudewrong
# Out:
# Empty DataFrame
# Columns: [Number, StructureName, StructureType, Condition of Bridge, TotalWidth, TotalLength, ConstructionYear, NumberOfSpan, Zone, Circle, Division, Sub-Division, RoadNo, StructureLRPName, ReferenceLRPNo, LocationLRPOffset, LocationChainage, LatitudeDegree, LatitudeMinute, LatitudeSecond, LongitudeDegree, LongitudeMinute, LongitudeSecond, BCS1TotalScore, LatitudeDecimal, LongitudeDecimal]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Drop the bridge that has swapped the value for longitude and latitude
Bridgelatitudewrongindex = list(Bridgelatitudewrong.index)
Bridge.drop(Bridgelatitudewrongindex,axis=0,inplace=True)
# Out:
# C:\Users\marlo\.anaconda\Python anaconda 3.8\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
