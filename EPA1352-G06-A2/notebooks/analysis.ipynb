# %% [markdown]
# ## Analysis of duration data

# %% [markdown]
# ### Import and load data

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the data from Pickle file. `durations` is a dict object with for each scenario all the durations of the trucks. For example `durations[2]` contains all the durations for the trucks in scenario 2.

# %%
durations = pickle.load(open("../data/durations.pickle", "rb"))
print(type(durations))
# Out:
# <class 'dict'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <module>
#       1 durations = pickle.load(open("../data/durations.pickle", "rb"))
#       2 print(type(durations))
# ----> 3 durations.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %% [markdown]
# ### Analysis

# %%
# sns.histplot(data = durations[8])
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(20, 16))
fig.suptitle('Bar plot of the destribution of travel time of all the trucks per scenario')

sns.histplot(ax=axs[0,0], data=durations[0])
axs[0,0].set_xlabel('Duration to travel the N1 in scenario 0', fontsize=14)

sns.histplot(ax=axs[0,1], data=durations[1])
axs[0,1].set_xlabel('Duration to travel the N1 in scenario 1', fontsize=14)

sns.histplot(ax=axs[1,0], data=durations[2])
axs[1,0].set_xlabel('Duration to travel the N1 in scenario 2', fontsize=14)

sns.histplot(ax=axs[1,1], data=durations[3])
axs[1,1].set_xlabel('Duration to travel the N1 in scenario 3', fontsize=14)

sns.histplot(ax=axs[2,0], data=durations[4])
axs[2,0].set_xlabel('Duration to travel the N1 in scenario 4', fontsize=14)

sns.histplot(ax=axs[2,1], data=durations[5])
axs[2,1].set_xlabel('Duration to travel the N1 in scenario 5', fontsize=14)

sns.histplot(ax=axs[3,0], data=durations[6])
axs[3,0].set_xlabel('Duration to travel the N1 in scenario 6', fontsize=14)

sns.histplot(ax=axs[3,1], data=durations[7])
axs[3,1].set_xlabel('Duration to travel the N1 in scenario 7', fontsize=14)

sns.histplot(ax=axs[4,0], data=durations[8])
axs[4,0].set_xlabel('Duration to travel the N1 in scenario 8', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <module>
#      26 sns.histplot(ax=axs[3,1], data=durations[7])
#      27 axs[3,1].set_xlabel('Duration to travel the N1 in scenario 7', fontsize=14)
# ---> 29 sns.histplot(ax=axs[4,0], data=durations[8])
#      30 axs[4,0].set_xlabel('Duration to travel the N1 in scenario 8', fontsize=14)
#      31 plt.show()
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
for i in range (8):
    x = len(durations[i])
    print(x)
#len(durations[0])
# Out:
# 1326
# 1295
# 1313
# 1280
# 1193
# 1229
# 1030
# 954
